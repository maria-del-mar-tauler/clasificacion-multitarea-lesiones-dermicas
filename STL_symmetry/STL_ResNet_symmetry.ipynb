# %% [markdown]
#  ## STL Symmetry - ResNet50 (CUT_LAYER=39) + K-Fold + GradCAM

# %%
import os
import json
import time
import datetime as dt
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns

import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    balanced_accuracy_score, classification_report, confusion_matrix,
    roc_auc_score, ConfusionMatrixDisplay, precision_score, recall_score,
    f1_score, cohen_kappa_score,
)
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
### Nota importante:
# He eliminado ISIC_0028189 del conjunto de train, porque era corrupta.
# Out:
# 2026-04-26 20:25:26.856027: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %%
train_csv  = "/home/marc/MARIADELMAR_EXPERIMENTS/onehot_files/train_onehot.csv"
val_csv    = "/home/marc/MARIADELMAR_EXPERIMENTS/onehot_files/val_onehot.csv"
test_csv   = "/home/marc/MARIADELMAR_EXPERIMENTS/onehot_files/test_onehot.csv"
images_dir = "/home/marc/MARIADELMAR_EXPERIMENTS/dataverse_files/images"


# class_cols ya NO se usa en symmetry, pero lo dejamos por compatibilidad

IMG_SIZE    = (224, 224)
BATCH_SIZE  = 32
NUM_CLASSES = 3
N_FOLDS     = 5
class_cols  = ["dx_akiec", "dx_bcc", "dx_bkl", "dx_df", "dx_mel", "dx_nv", "dx_vasc"]
class_names = ["2_ejes", "1_eje", "asimetrica"]   #clases de symmetry
CUT_LAYER   = 39

WARMUP_EPOCHS, FT_EPOCHS = 30, 30
WARMUP_LR = 1e-3          # LR warmup (solo heads)
FT_LR     = 5e-5          # LR fine-tuning (todo el modelo descongelado)
TASK_NAME   = "symmetry"   

EXP_DIR = Path("ResNet50_STL") / f"exp_{dt.datetime.now():%Y-%m-%d_%H-%M}_{TASK_NAME}_CUT{CUT_LAYER}_{N_FOLDS}fold"
EXP_DIR.mkdir(parents=True, exist_ok=True)
print(f"Experimento STL ({TASK_NAME}) en: {EXP_DIR.resolve()}")
# Out:
# Experimento STL (symmetry) en: /home/marc/MARIADELMAR_EXPERIMENTS/STL_Symmetry_experimentos/ResNet50_STL/exp_2026-04-26_20-25_symmetry_CUT39_5fold

# %%
df_train = pd.read_csv(train_csv)
df_val   = pd.read_csv(val_csv)
df_test  = pd.read_csv(test_csv)

# CSV de symmetry (¡importante!)
df_sym   = pd.read_csv("/home/marc/MARIADELMAR_EXPERIMENTS/ham10000_shape_symmetry_ALL.csv")

print(f"CSVs - train: {len(df_train)}  val: {len(df_val)}  test: {len(df_test)}")
print(f"Symmetry CSV - total: {len(df_sym)}")

# Renombrar columna y merge con cada split
df_sym = df_sym.rename(columns={"image": "image_id"})
df_sym = df_sym[["image_id", "shape_symmetry"]]

def merge_with_sym(df, name):
    before = len(df)
    merged = df.merge(df_sym, on="image_id", how="inner")
    lost   = before - len(merged)
    if lost > 0:
        print(f"  [WARN] {name}: perdidas {lost} imágenes sin entrada en symmetry CSV")
    else:
        print(f"  {name}: merge OK, 0 imágenes perdidas")
    return merged

print("\nMerge con CSV de symmetry:")
df_train = merge_with_sym(df_train, "train")
df_val   = merge_with_sym(df_val,   "val")
df_test  = merge_with_sym(df_test,  "test")

for df in (df_train, df_val, df_test):
    df["filepath"] = df["image_id"].apply(lambda x: os.path.join(images_dir, f"{x}.jpg"))

# Etiquetas de symmetry (one-hot)
def to_onehot_sym(df):
    y = np.zeros((len(df), NUM_CLASSES), dtype="float32")
    y[np.arange(len(df)), df["shape_symmetry"].values] = 1.0
    return y

y_train = to_onehot_sym(df_train)
y_val   = to_onehot_sym(df_val)
y_test  = to_onehot_sym(df_test)

df_trainval    = pd.concat([df_train, df_val], ignore_index=True)
y_trainval     = np.concatenate([y_train, y_val], axis=0)
y_trainval_int = np.argmax(y_trainval, axis=1)
y_test_int     = np.argmax(y_test, axis=1)

print("\n" + "="*60)
print(f"DISTRIBUCIÓN DE ETIQUETAS - tarea: {TASK_NAME}")
print("="*60)
for i, c in enumerate(class_names):
    n = (y_trainval_int == i).sum()
    print(f"  {c:<12} {n:>5}  ({100*n/len(y_trainval_int):.1f}%)")
print(f"\nTest set fijo: {len(df_test)} imágenes")

# Class weights balanceados
cw = compute_class_weight(class_weight="balanced",
                           classes=np.arange(NUM_CLASSES),
                           y=y_trainval_int)
CW = tf.constant(cw, dtype=tf.float32)
class_weight_dict = {i: float(cw[i]) for i in range(NUM_CLASSES)}
print(f"\nClass weights: {cw.round(3)}")
# Out:
# CSVs — train: 6008  val: 2003  test: 2003
# Symmetry CSV — total: 10015
#
# Merge con CSV de symmetry:
#   train: merge OK, 0 imágenes perdidas
#   val: merge OK, 0 imágenes perdidas
#   test: merge OK, 0 imágenes perdidas
#
# ============================================================
# DISTRIBUCIÓN DE ETIQUETAS — tarea: symmetry
# ============================================================
#   2_ejes        4785  (59.7%)
#   1_eje         2468  (30.8%)
#   asimetrica     758  (9.5%)
#
# Test set fijo: 2003 imágenes
#
# Class weights: [0.558 1.082 3.523]
# 2026-04-26 20:25:27.905481: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2026-04-26 20:25:27.935191: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:05:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2026-04-26 20:25:27.935240: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2026-04-26 20:25:27.937209: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2026-04-26 20:25:27.938957: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2026-04-26 20:25:27.939255: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2026-04-26 20:25:27.941268: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2026-04-26 20:25:27.942322: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2026-04-26 20:25:27.946437: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2026-04-26 20:25:27.948218: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2026-04-26 20:25:27.948627: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-26 20:25:27.956652: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 3597735000 Hz
# 2026-04-26 20:25:27.957503: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x67f3620 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2026-04-26 20:25:27.957520: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2026-04-26 20:25:28.086180: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x685f9b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-04-26 20:25:28.086209: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): GeForce GTX 1080 Ti, Compute Capability 6.1
# 2026-04-26 20:25:28.087140: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:05:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2026-04-26 20:25:28.087192: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2026-04-26 20:25:28.087219: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2026-04-26 20:25:28.087238: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2026-04-26 20:25:28.087257: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2026-04-26 20:25:28.087276: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2026-04-26 20:25:28.087295: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2026-04-26 20:25:28.087315: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2026-04-26 20:25:28.088865: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2026-04-26 20:25:28.088911: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2026-04-26 20:25:28.491849: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2026-04-26 20:25:28.491880: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2026-04-26 20:25:28.491887: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2026-04-26 20:25:28.493311: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10216 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:05:00.0, compute capability: 6.1)

# %%
def load_image(filepath, y):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32)
    img = tf.keras.applications.resnet.preprocess_input(img)   
    return img, y

def load_image_aug(filepath, y):
    img = tf.io.read_file(filepath)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32)
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_flip_up_down(img)
    img = tf.image.random_brightness(img, max_delta=0.2)
    img = tf.image.random_contrast(img, lower=0.8, upper=1.2)
    img = tf.clip_by_value(img, 0.0, 255.0)
    img = tf.keras.applications.resnet.preprocess_input(img)   
    return img, y

def make_dataset(filepaths, y, training=False):
    ds = tf.data.Dataset.from_tensor_slices((filepaths, y))
    if training:
        ds = ds.shuffle(buffer_size=len(filepaths), reshuffle_each_iteration=True)
    ds = ds.map(load_image_aug if training else load_image, num_parallel_calls=15)
    ds = ds.batch(BATCH_SIZE).prefetch(50)
    return ds

test_ds = make_dataset(df_test["filepath"].values, y_test, training=False)

print("Sanity check:")
for imgs, y in test_ds.take(1):
    print(f"  imgs: {imgs.shape}  y: {y.shape}")
# Out:
# Sanity check:
#   imgs: (32, 224, 224, 3)  y: (32, 3)

# %%
def build_model():
    base_model = tf.keras.applications.ResNet50(             
        include_top=False, weights="imagenet",
        input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3),
    )
    base_model.trainable = False
    inputs = tf.keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3), name="input_image")
    x = base_model(inputs, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D(name="gap")(x)
    shared = tf.keras.layers.Dense(256, activation="relu", name="shared_dense")(x)
    shared = tf.keras.layers.Dropout(0.3, name="shared_dropout")(shared)
    out = tf.keras.layers.Dense(NUM_CLASSES, activation="softmax", name="head_sym")(shared)
    model = tf.keras.Model(inputs=inputs, outputs=out, name="STL_ResNet50_sym")  
    return model, base_model

# Visualización
_tmp_m, _tmp_b = build_model()
_tmp_m.summary()
tf.keras.utils.plot_model(_tmp_m, to_file=str(EXP_DIR / "00_model_architecture.png"),
                           show_shapes=True, show_layer_names=True,
                           expand_nested=True, dpi=150)
del _tmp_m, _tmp_b
tf.keras.backend.clear_session()
# Out:
# Model: "STL_ResNet50_sym"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_image (InputLayer)     [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# gap (GlobalAveragePooling2D) (None, 2048)              0
# _________________________________________________________________
# shared_dense (Dense)         (None, 256)               524544
# _________________________________________________________________
# shared_dropout (Dropout)     (None, 256)               0
# _________________________________________________________________
# head_sym (Dense)             (None, 3)                 771
# =================================================================
# Total params: 24,113,027
# Trainable params: 525,315
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
def unfreeze_from(base_model, cut_layer):
    base_model.trainable = True
    for layer in base_model.layers:
        layer.trainable = False
    for i, layer in enumerate(base_model.layers):
        if i >= cut_layer:
            layer.trainable = True
    trainable = sum(l.count_params() for l in base_model.layers if l.trainable)
    total     = base_model.count_params()
    print(f"cut_layer={cut_layer} -> {trainable:,}/{total:,} params trainable "
          f"({100*trainable/total:.1f}%)")

print("Helper unfreeze listo.")
# Out:
# Helper unfreeze listo.

# %%
def train_one_fold(fold_idx, train_idx, val_idx, fold_dir):
    fold_dir.mkdir(exist_ok=True)
    print(f"\n{'='*70}\nFOLD {fold_idx}/{N_FOLDS} - STL {TASK_NAME}\n{'='*70}")

    df_tr = df_trainval.iloc[train_idx].reset_index(drop=True)
    df_vl = df_trainval.iloc[val_idx].reset_index(drop=True)
    y_tr = to_onehot_sym(df_tr)   
    y_vl = to_onehot_sym(df_vl)   

    print(f"  train={len(df_tr)}  val={len(df_vl)}  test(fijo)={len(df_test)}")

    train_ds = make_dataset(df_tr["filepath"].values, y_tr, training=True)
    val_ds   = make_dataset(df_vl["filepath"].values, y_vl, training=False)

    model, base_model = build_model()

    #FASE 1: WARMUP 
    print(f"\n--- FASE 1: warmup (head only, LR={WARMUP_LR}) ---")
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=WARMUP_LR),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )
    callbacks_warmup = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss", patience=7, min_delta=0.005,
            restore_best_weights=True, verbose=1),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss", factor=0.5, patience=3, min_lr=1e-7, verbose=1),
    ]
    t0 = time.time()
    h1 = model.fit(train_ds, validation_data=val_ds, epochs=WARMUP_EPOCHS,
                    class_weight=class_weight_dict,
                    callbacks=callbacks_warmup, verbose=2)
    t_warmup = time.time() - t0

    #FASE 2: FINE-TUNING 
    print(f"\n--- FASE 2: fine-tuning (CUT_LAYER={CUT_LAYER}, LR={FT_LR}) ---")
    unfreeze_from(base_model, CUT_LAYER)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=FT_LR),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )
    callbacks_ft = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss", patience=8, min_delta=0.005,
            restore_best_weights=True, verbose=1),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss", factor=0.5, patience=3, min_lr=1e-7, verbose=1),
    ]
    t0 = time.time()
    h2 = model.fit(train_ds, validation_data=val_ds, epochs=FT_EPOCHS,
                    class_weight=class_weight_dict,
                    callbacks=callbacks_ft, verbose=2)
    t_ft = time.time() - t0

    #History combinada 
    h1_dict = h1.history
    h2_dict = h2.history
    history = {k: list(h1_dict.get(k, [])) + list(h2_dict.get(k, [])) for k in h1_dict}
    pd.DataFrame(history).to_csv(fold_dir / "history.csv", index=False)

    #Evaluación sobre test 
    print(f"\n--- Evaluación sobre test ({len(df_test)} imgs) ---")
    t0 = time.time()
    y_pred_proba = model.predict(test_ds, verbose=0)
    t_predict = time.time() - t0
    y_pred_int = np.argmax(y_pred_proba, axis=1)

    metrics = {
        "fold":           fold_idx,
        "time_warmup_s":  round(t_warmup, 1),
        "time_ft_s":      round(t_ft, 1),
        "time_total_s":   round(t_warmup + t_ft, 1),
        "time_predict_s": round(t_predict, 2),
        "epochs_warmup":  len(h1_dict["loss"]),
        "epochs_ft":      len(h2_dict["loss"]),
        "len_warmup":     len(h1_dict["loss"]),
        f"{TASK_NAME}_acc":             float((y_test_int == y_pred_int).mean()),
        f"{TASK_NAME}_balanced_acc":    float(balanced_accuracy_score(y_test_int, y_pred_int)),
        f"{TASK_NAME}_precision_macro": float(precision_score(y_test_int, y_pred_int, average="macro", zero_division=0)),   
        f"{TASK_NAME}_recall_macro":    float(recall_score(y_test_int, y_pred_int, average="macro", zero_division=0)),       
        f"{TASK_NAME}_f1_macro":        float(f1_score(y_test_int, y_pred_int, average="macro", zero_division=0)),
        f"{TASK_NAME}_f1_weighted":     float(f1_score(y_test_int, y_pred_int, average="weighted", zero_division=0)),
        f"{TASK_NAME}_kappa":           float(cohen_kappa_score(y_test_int, y_pred_int)),
    }
    try:
        y_true_onehot = np.eye(NUM_CLASSES)[y_test_int]
        metrics[f"{TASK_NAME}_auc_macro"] = float(
            roc_auc_score(y_true_onehot, y_pred_proba, multi_class="ovr", average="macro"))
    except Exception:
        metrics[f"{TASK_NAME}_auc_macro"] = float("nan")

    (fold_dir / "metrics.json").write_text(json.dumps(metrics, indent=2))

    rpt = classification_report(y_test_int, y_pred_int,
                                 target_names=class_names, digits=4)
    (fold_dir / f"classification_report_{TASK_NAME}.txt").write_text(rpt)
    print(f"\n--- {TASK_NAME.upper()} ---\n{rpt}")

    cm = confusion_matrix(y_test_int, y_pred_int)
    np.save(fold_dir / f"confusion_matrix_{TASK_NAME}.npy", cm)
    fig, ax = plt.subplots(figsize=(7, 5))
    ConfusionMatrixDisplay(cm, display_labels=class_names).plot(
        ax=ax, cmap="Blues", xticks_rotation=45, colorbar=True)
    ax.set_title(f"Fold {fold_idx} - {TASK_NAME} (test)")
    plt.tight_layout()
    plt.savefig(fold_dir / f"confusion_matrix_{TASK_NAME}.png", dpi=100)
    plt.show()

    model.save_weights(str(fold_dir / "best_weights"), save_format="tf")
    print(f"  Pesos guardados en: {fold_dir / 'best_weights'}")

    return {
        "metrics":      metrics,
        "y_pred_int":   y_pred_int,
        "y_pred_proba": y_pred_proba,
        "h1_history":   h1_dict,
        "h2_history":   h2_dict,
    }

print("train_one_fold STL listo.")
# Out:
# train_one_fold STL listo.

# %%
skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=42)
all_fold_metrics = []
histories_warmup = []
histories_ft     = []
t_exp_start      = time.time()

for fold_idx, (train_idx, val_idx) in enumerate(
        skf.split(np.zeros(len(df_trainval)), y_trainval_int), 1):
    fold_dir = EXP_DIR / f"fold_{fold_idx}"
    result   = train_one_fold(fold_idx, train_idx, val_idx, fold_dir)
    all_fold_metrics.append(result["metrics"])
    histories_warmup.append(result["h1_history"])
    histories_ft.append(result["h2_history"])
    del result
    tf.keras.backend.clear_session()

t_exp_total = time.time() - t_exp_start
print(f"\n{'='*70}")
print(f"*** Experimento STL {TASK_NAME} completo en {t_exp_total/60:.1f} min ***")
print(f"{'='*70}")

df_metrics = pd.DataFrame(all_fold_metrics)
df_metrics.to_csv(EXP_DIR / "all_folds_metrics.csv", index=False)

# Summary con mediana
numeric  = [c for c in df_metrics.columns
            if c != "fold" and pd.api.types.is_numeric_dtype(df_metrics[c])]
summary  = df_metrics[numeric].agg(["mean", "median", "std"]).T
summary.columns = ["mean", "median", "std"]
summary["mean±std"] = summary.apply(
    lambda r: f"{r['mean']:.4f} ± {r['std']:.4f}", axis=1)
summary.to_csv(EXP_DIR / "summary_mean_median_std.csv")

print("\n" + "="*70)
print(f"RESUMEN ENTRE {N_FOLDS} FOLDS - STL {TASK_NAME}")
print("="*70)
print(summary[["mean", "median", "std"]])
print(f"\nGuardado en: {EXP_DIR}")


#Funciones de curvas
def _hist_to_dict(h):
    return h.history if hasattr(h, "history") else h

def _pad_to_len(arr, max_len):
    arr = np.asarray(arr, dtype=np.float32)
    out = np.full((max_len,), np.nan, dtype=np.float32)
    out[:min(len(arr), max_len)] = arr[:min(len(arr), max_len)]
    return out

def _stack_metric(histories, key):
    hs      = [_hist_to_dict(h) for h in histories]
    lens    = [len(h.get(key, [])) for h in hs]
    max_len = max(lens) if lens else 0
    if max_len == 0:
        return np.empty((0, 0), dtype=np.float32), 0
    stacked = np.vstack([_pad_to_len(h.get(key, []), max_len) for h in hs]).astype(np.float32)
    return stacked, max_len


def plot_cv_mean_std(histories, save_dir, prefix, band_alpha=0.20):
    os.makedirs(save_dir, exist_ok=True)
    keys = {"loss": ("loss", "val_loss"), "accuracy": ("accuracy", "val_accuracy")}
    stacked, max_len = {}, 0
    for name, (k_tr, k_va) in keys.items():
        tr, ml = _stack_metric(histories, k_tr)
        va, _  = _stack_metric(histories, k_va)
        stacked[name] = (tr, va)
        max_len = max(max_len, ml)
    epochs = np.arange(1, max_len + 1)

    def mean_std(x):
        if x.size == 0:
            return np.full((max_len,), np.nan), np.full((max_len,), np.nan)
        return np.nanmean(x, axis=0), np.nanstd(x, axis=0)

    plt.figure(figsize=(14, 5))
    for i, name in enumerate(["loss", "accuracy"], 1):
        tr, va = stacked[name]
        m_tr, s_tr = mean_std(tr); m_va, s_va = mean_std(va)
        plt.subplot(1, 2, i)
        plt.plot(epochs, m_tr, linewidth=2, label=f"train {name} mean")
        plt.fill_between(epochs, m_tr - s_tr, m_tr + s_tr, alpha=band_alpha)
        plt.plot(epochs, m_va, linewidth=2, linestyle="--", label=f"val {name} mean")
        plt.fill_between(epochs, m_va - s_va, m_va + s_va, alpha=band_alpha)
        plt.title(f"{prefix} - {name} (mean ± std entre folds)")
        plt.xlabel("epoch"); plt.ylabel(name)
        plt.grid(True, alpha=0.3); plt.legend()
    plt.tight_layout()
    fig_path = os.path.join(save_dir, f"{prefix}_cv_mean_std.png")
    plt.savefig(fig_path, dpi=300); plt.show()
    return fig_path


def plot_cv_combined(histories_warmup, histories_ft, save_dir, prefix="combined"):
    """Warmup + FT en un único gráfico con línea divisoria."""
    os.makedirs(save_dir, exist_ok=True)
    histories_full, len_warmups = [], []
    for h1, h2 in zip(histories_warmup, histories_ft):
        combined = {k: list(h1.get(k, [])) + list(h2.get(k, [])) for k in h1}
        histories_full.append(combined)
        len_warmups.append(len(h1["loss"]))
    sep_epoch = int(round(np.mean(len_warmups)))

    keys = {"Loss":     ("loss", "val_loss"),
            "Accuracy": ("accuracy", "val_accuracy")}

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for ax, (title, (k_tr, k_va)) in zip(axes, keys.items()):
        tr_stk, ml = _stack_metric(histories_full, k_tr)
        va_stk, _  = _stack_metric(histories_full, k_va)
        epochs = np.arange(1, ml + 1)
        m_tr = np.nanmean(tr_stk, axis=0); s_tr = np.nanstd(tr_stk, axis=0)
        m_va = np.nanmean(va_stk, axis=0); s_va = np.nanstd(va_stk, axis=0)

        ax.plot(epochs, m_tr, linewidth=2, label="train mean", color="C0")
        ax.fill_between(epochs, m_tr - s_tr, m_tr + s_tr, alpha=0.2, color="C0")
        ax.plot(epochs, m_va, linewidth=2, linestyle="--", label="val mean", color="C1")
        ax.fill_between(epochs, m_va - s_va, m_va + s_va, alpha=0.2, color="C1")

        ax.axvline(sep_epoch, color="gray", linewidth=1.5, linestyle="--",
                   label=f"inicio FT (epoch {sep_epoch})")
        ax.set_title(f"{title} - warmup + fine-tuning (mean ± std)")
        ax.set_xlabel("Epoch global"); ax.set_ylabel(title)
        ax.legend(fontsize=8); ax.grid(alpha=0.3)

    plt.tight_layout()
    fig_path = os.path.join(save_dir, f"{prefix}_full_training.png")
    plt.savefig(fig_path, dpi=300)
    plt.show()
    print(f"  Gráfica conjunta guardada: {fig_path}")
    return fig_path


#Generar plots
save_dir = str(EXP_DIR / "training_plots_cv")

print("\n Fase 1 (warmup)")
fig1 = plot_cv_mean_std(histories_warmup, save_dir=save_dir, prefix="phase1_warmup")

print("\n Fase 2 (fine-tuning)")
fig2 = plot_cv_mean_std(histories_ft, save_dir=save_dir, prefix="phase2_finetune")

print("\n Entrenamiento completo (warmup + FT combinados)")
fig_combined = plot_cv_combined(histories_warmup, histories_ft,
                                 save_dir=save_dir, prefix="combined")


#Matriz de confusión agregada 
print("\n>>> Matriz de confusión agregada entre folds")
cms = []
for k in range(1, N_FOLDS + 1):
    cm_path = EXP_DIR / f"fold_{k}" / f"confusion_matrix_{TASK_NAME}.npy"
    if cm_path.exists():
        cms.append(np.load(cm_path))

if cms:
    cm_sum  = np.sum(cms, axis=0)
    cm_mean = cm_sum.astype(float) / len(cms)
    cm_norm = cm_sum.astype(float) / cm_sum.sum(axis=1, keepdims=True)
    cm_norm = np.nan_to_num(cm_norm)

    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    sns.heatmap(cm_mean, annot=True, fmt=".1f", cmap="Blues",
                xticklabels=class_names, yticklabels=class_names, ax=axes[0])
    axes[0].set_title(f"{TASK_NAME} - CM promediada entre {len(cms)} folds")
    axes[0].set_xlabel("Predicho"); axes[0].set_ylabel("Real")

    sns.heatmap(cm_norm, annot=True, fmt=".2%", cmap="Blues",
                xticklabels=class_names, yticklabels=class_names, ax=axes[1])
    axes[1].set_title(f"{TASK_NAME} - CM normalizada por fila (recall)")
    axes[1].set_xlabel("Predicho"); axes[1].set_ylabel("Real")

    plt.tight_layout()
    out = EXP_DIR / f"confusion_matrix_{TASK_NAME}_aggregated.png"
    plt.savefig(out, dpi=150, bbox_inches="tight")
    plt.show()
    print(f"  Guardado: {out}")
else:
    print("  [AVISO] No se encontraron CMs por fold")
# Out:
# ======================================================================
# FOLD 1/5 — STL symmetry
# ======================================================================
#   train=6408  val=1603  test(fijo)=2003
#
# --- FASE 1: warmup (head only, LR=0.001) ---
# Epoch 1/30
# 2026-04-26 20:25:38.844411: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2026-04-26 20:25:39.075225: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 201/201 - 17s - loss: 1.1596 - accuracy: 0.4290 - val_loss: 1.0620 - val_accuracy: 0.4161
# Epoch 2/30
# 201/201 - 16s - loss: 1.0189 - accuracy: 0.4894 - val_loss: 0.9994 - val_accuracy: 0.5003
# Epoch 3/30
# 201/201 - 16s - loss: 1.0028 - accuracy: 0.4860 - val_loss: 1.0005 - val_accuracy: 0.4941
# Epoch 4/30
# 201/201 - 16s - loss: 0.9894 - accuracy: 0.4958 - val_loss: 0.9625 - val_accuracy: 0.5184
# Epoch 5/30
# 201/201 - 16s - loss: 0.9821 - accuracy: 0.4970 - val_loss: 1.0117 - val_accuracy: 0.4772
# Epoch 6/30
# 201/201 - 16s - loss: 0.9687 - accuracy: 0.5078 - val_loss: 0.9508 - val_accuracy: 0.5153
# Epoch 7/30
# 201/201 - 16s - loss: 0.9654 - accuracy: 0.5073 - val_loss: 1.0791 - val_accuracy: 0.4198
# Epoch 8/30
# 201/201 - 16s - loss: 0.9572 - accuracy: 0.5119 - val_loss: 0.8616 - val_accuracy: 0.5596
# Epoch 9/30
# 201/201 - 17s - loss: 0.9459 - accuracy: 0.5169 - val_loss: 0.9761 - val_accuracy: 0.4966
# Epoch 10/30
# 201/201 - 16s - loss: 0.9275 - accuracy: 0.5165 - val_loss: 0.9028 - val_accuracy: 0.5315
# Epoch 11/30
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 201/201 - 16s - loss: 0.9252 - accuracy: 0.5229 - val_loss: 0.9716 - val_accuracy: 0.4959
# Epoch 12/30
# 201/201 - 16s - loss: 0.8984 - accuracy: 0.5353 - val_loss: 0.9334 - val_accuracy: 0.5190
# Epoch 13/30
# 201/201 - 16s - loss: 0.8822 - accuracy: 0.5531 - val_loss: 0.9734 - val_accuracy: 0.5022
# Epoch 14/30
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 201/201 - 16s - loss: 0.8705 - accuracy: 0.5551 - val_loss: 0.9000 - val_accuracy: 0.5259
# Epoch 15/30
# Restoring model weights from the end of the best epoch.
# 201/201 - 17s - loss: 0.8484 - accuracy: 0.5546 - val_loss: 0.9171 - val_accuracy: 0.5147
# Epoch 00015: early stopping
#
# --- FASE 2: fine-tuning (CUT_LAYER=39, LR=5e-05) ---
# cut_layer=39 → 23,357,952/23,587,712 params trainable (99.0%)
# Epoch 1/30
# 201/201 - 35s - loss: 1.0771 - accuracy: 0.4228 - val_loss: 1.0643 - val_accuracy: 0.5022
# Epoch 2/30
# 201/201 - 34s - loss: 1.0316 - accuracy: 0.4700 - val_loss: 0.9838 - val_accuracy: 0.5583
# Epoch 3/30
# 201/201 - 34s - loss: 0.9678 - accuracy: 0.5192 - val_loss: 0.9538 - val_accuracy: 0.4947
# Epoch 4/30
# 201/201 - 34s - loss: 0.8996 - accuracy: 0.5507 - val_loss: 1.0055 - val_accuracy: 0.4841
# Epoch 5/30
# 201/201 - 34s - loss: 0.8905 - accuracy: 0.5543 - val_loss: 0.8390 - val_accuracy: 0.5745
# Epoch 6/30
# 201/201 - 34s - loss: 0.8444 - accuracy: 0.5772 - val_loss: 0.7390 - val_accuracy: 0.6513
# Epoch 7/30
# 201/201 - 34s - loss: 0.8200 - accuracy: 0.5922 - val_loss: 0.8348 - val_accuracy: 0.5827
# Epoch 8/30
# 201/201 - 34s - loss: 0.8016 - accuracy: 0.5886 - val_loss: 0.7711 - val_accuracy: 0.6051
# Epoch 9/30
# 201/201 - 34s - loss: 0.7758 - accuracy: 0.6035 - val_loss: 0.7157 - val_accuracy: 0.6519
# Epoch 10/30
# 201/201 - 34s - loss: 0.7409 - accuracy: 0.6214 - val_loss: 0.8784 - val_accuracy: 0.5758
# Epoch 11/30
# 201/201 - 34s - loss: 0.7275 - accuracy: 0.6262 - val_loss: 0.8309 - val_accuracy: 0.5845
# Epoch 12/30
# 201/201 - 34s - loss: 0.7200 - accuracy: 0.6344 - val_loss: 0.7130 - val_accuracy: 0.6575
# Epoch 13/30
# 201/201 - 34s - loss: 0.6682 - accuracy: 0.6617 - val_loss: 0.7697 - val_accuracy: 0.6276
# Epoch 14/30
# 201/201 - 34s - loss: 0.6594 - accuracy: 0.6650 - val_loss: 0.8484 - val_accuracy: 0.5876
# Epoch 15/30
# 201/201 - 34s - loss: 0.6231 - accuracy: 0.6777 - val_loss: 0.7076 - val_accuracy: 0.6750
# Epoch 16/30
# 201/201 - 34s - loss: 0.6024 - accuracy: 0.6871 - val_loss: 0.7315 - val_accuracy: 0.6600
# Epoch 17/30
# 201/201 - 34s - loss: 0.5765 - accuracy: 0.7079 - val_loss: 0.9489 - val_accuracy: 0.5552
# Epoch 18/30
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 201/201 - 34s - loss: 0.5531 - accuracy: 0.7080 - val_loss: 0.8569 - val_accuracy: 0.6301
# Epoch 19/30
# 201/201 - 34s - loss: 0.4611 - accuracy: 0.7519 - val_loss: 0.7876 - val_accuracy: 0.6625
# Epoch 20/30
# 201/201 - 34s - loss: 0.4284 - accuracy: 0.7675 - val_loss: 0.8617 - val_accuracy: 0.6313
# Epoch 21/30
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 201/201 - 34s - loss: 0.3958 - accuracy: 0.7939 - val_loss: 0.8895 - val_accuracy: 0.6157
# Epoch 22/30
# 201/201 - 34s - loss: 0.3427 - accuracy: 0.8180 - val_loss: 0.9443 - val_accuracy: 0.6588
# Epoch 23/30
# Restoring model weights from the end of the best epoch.
# 201/201 - 34s - loss: 0.3247 - accuracy: 0.8251 - val_loss: 0.9297 - val_accuracy: 0.6681
# Epoch 00023: early stopping
#
# --- Evaluación sobre test (2003 imgs) ---
#
# --- SYMMETRY ---
#               precision    recall  f1-score   support
#
#       2_ejes     0.7905    0.7748    0.7826      1208
#        1_eje     0.4766    0.4884    0.4824       604
#   asimetrica     0.4200    0.4398    0.4297       191
#
#     accuracy                         0.6565      2003
#    macro avg     0.5624    0.5677    0.5649      2003
# weighted avg     0.6605    0.6565    0.6584      2003
#   Pesos guardados en: ResNet50_STL/exp_2026-04-26_20-25_symmetry_CUT39_5fold/fold_1/best_weights
#
# ======================================================================
# FOLD 2/5 — STL symmetry
# ======================================================================
#   train=6409  val=1602  test(fijo)=2003
#
# --- FASE 1: warmup (head only, LR=0.001) ---
# Epoch 1/30
# 201/201 - 17s - loss: 1.1841 - accuracy: 0.4450 - val_loss: 0.9715 - val_accuracy: 0.5531
# Epoch 2/30
# 201/201 - 16s - loss: 1.0130 - accuracy: 0.4901 - val_loss: 0.9566 - val_accuracy: 0.5119
# Epoch 3/30
# 201/201 - 16s - loss: 0.9897 - accuracy: 0.5094 - val_loss: 1.0191 - val_accuracy: 0.4551
# Epoch 4/30
# 201/201 - 16s - loss: 0.9828 - accuracy: 0.4932 - val_loss: 1.0442 - val_accuracy: 0.4401
# Epoch 5/30
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 201/201 - 16s - loss: 0.9641 - accuracy: 0.4931 - val_loss: 0.9926 - val_accuracy: 0.4819
# Epoch 6/30
# 201/201 - 16s - loss: 0.9363 - accuracy: 0.5168 - val_loss: 1.0170 - val_accuracy: 0.4682
# Epoch 7/30
# 201/201 - 16s - loss: 0.9324 - accuracy: 0.5219 - val_loss: 1.0084 - val_accuracy: 0.4800
# Epoch 8/30
# 201/201 - 16s - loss: 0.9192 - accuracy: 0.5236 - val_loss: 0.9318 - val_accuracy: 0.5262
# Epoch 9/30
# 201/201 - 16s - loss: 0.9131 - accuracy: 0.5213 - val_loss: 0.9277 - val_accuracy: 0.5256
# Epoch 10/30
# 201/201 - 16s - loss: 0.9115 - accuracy: 0.5327 - val_loss: 1.0750 - val_accuracy: 0.4382
# Epoch 11/30
# 201/201 - 16s - loss: 0.8992 - accuracy: 0.5394 - val_loss: 0.9669 - val_accuracy: 0.5031
# Epoch 12/30
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 201/201 - 16s - loss: 0.8903 - accuracy: 0.5427 - val_loss: 0.9822 - val_accuracy: 0.4969
# Epoch 13/30
# 201/201 - 17s - loss: 0.8480 - accuracy: 0.5575 - val_loss: 0.9439 - val_accuracy: 0.5194
# Epoch 14/30
# 201/201 - 16s - loss: 0.8492 - accuracy: 0.5581 - val_loss: 0.9382 - val_accuracy: 0.5231
# Epoch 15/30
# Restoring model weights from the end of the best epoch.
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 201/201 - 16s - loss: 0.8364 - accuracy: 0.5689 - val_loss: 0.9724 - val_accuracy: 0.4969
# Epoch 00015: early stopping
#
# --- FASE 2: fine-tuning (CUT_LAYER=39, LR=5e-05) ---
# cut_layer=39 → 23,357,952/23,587,712 params trainable (99.0%)
# Epoch 1/30
# 201/201 - 35s - loss: 1.0746 - accuracy: 0.4221 - val_loss: 0.9390 - val_accuracy: 0.5581
# Epoch 2/30
# 201/201 - 34s - loss: 1.0113 - accuracy: 0.4874 - val_loss: 0.8960 - val_accuracy: 0.5587
# Epoch 3/30
# 201/201 - 34s - loss: 0.9258 - accuracy: 0.5411 - val_loss: 0.8146 - val_accuracy: 0.5899
# Epoch 4/30
# 201/201 - 34s - loss: 0.8829 - accuracy: 0.5767 - val_loss: 1.0202 - val_accuracy: 0.4938
# Epoch 5/30
# 201/201 - 34s - loss: 0.8533 - accuracy: 0.5706 - val_loss: 0.7801 - val_accuracy: 0.6223
# Epoch 6/30
# 201/201 - 34s - loss: 0.8132 - accuracy: 0.5962 - val_loss: 0.8810 - val_accuracy: 0.5699
# Epoch 7/30
# 201/201 - 34s - loss: 0.8005 - accuracy: 0.5965 - val_loss: 0.7567 - val_accuracy: 0.6330
# Epoch 8/30
# 201/201 - 34s - loss: 0.7899 - accuracy: 0.5979 - val_loss: 0.8345 - val_accuracy: 0.5787
# Epoch 9/30
# 201/201 - 34s - loss: 0.7530 - accuracy: 0.6227 - val_loss: 0.8347 - val_accuracy: 0.5780
# Epoch 10/30
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 201/201 - 34s - loss: 0.7245 - accuracy: 0.6302 - val_loss: 0.8137 - val_accuracy: 0.5993
# Epoch 11/30
# 201/201 - 34s - loss: 0.6350 - accuracy: 0.6666 - val_loss: 0.7891 - val_accuracy: 0.6336
# Epoch 12/30
# 201/201 - 34s - loss: 0.6100 - accuracy: 0.6794 - val_loss: 0.9181 - val_accuracy: 0.6099
# Epoch 13/30
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 201/201 - 34s - loss: 0.5748 - accuracy: 0.6945 - val_loss: 0.8536 - val_accuracy: 0.6267
# Epoch 14/30
# 201/201 - 34s - loss: 0.4951 - accuracy: 0.7293 - val_loss: 0.8618 - val_accuracy: 0.6442
# Epoch 15/30
# Restoring model weights from the end of the best epoch.
# 201/201 - 34s - loss: 0.4594 - accuracy: 0.7460 - val_loss: 0.9545 - val_accuracy: 0.5899
# Epoch 00015: early stopping
#
# --- Evaluación sobre test (2003 imgs) ---
#
# --- SYMMETRY ---
#               precision    recall  f1-score   support
#
#       2_ejes     0.7910    0.7425    0.7660      1208
#        1_eje     0.4458    0.4354    0.4405       604
#   asimetrica     0.3871    0.5654    0.4596       191
#
#     accuracy                         0.6331      2003
#    macro avg     0.5413    0.5811    0.5554      2003
# weighted avg     0.6484    0.6331    0.6386      2003
#   Pesos guardados en: ResNet50_STL/exp_2026-04-26_20-25_symmetry_CUT39_5fold/fold_2/best_weights
#
# ======================================================================
# FOLD 3/5 — STL symmetry
# ======================================================================
#   train=6409  val=1602  test(fijo)=2003
#
# --- FASE 1: warmup (head only, LR=0.001) ---
# Epoch 1/30
# 201/201 - 17s - loss: 1.1753 - accuracy: 0.4325 - val_loss: 1.1586 - val_accuracy: 0.3564
# Epoch 2/30
# 201/201 - 16s - loss: 1.0149 - accuracy: 0.4826 - val_loss: 0.9179 - val_accuracy: 0.5268
# Epoch 3/30
# 201/201 - 16s - loss: 0.9935 - accuracy: 0.4934 - val_loss: 1.0472 - val_accuracy: 0.4332
# Epoch 4/30
# 201/201 - 16s - loss: 0.9784 - accuracy: 0.5027 - val_loss: 0.9593 - val_accuracy: 0.4931
# Epoch 5/30
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 201/201 - 16s - loss: 0.9736 - accuracy: 0.5088 - val_loss: 1.0731 - val_accuracy: 0.4357
# Epoch 6/30
# 201/201 - 16s - loss: 0.9425 - accuracy: 0.5227 - val_loss: 0.9631 - val_accuracy: 0.4969
# Epoch 7/30
# 201/201 - 16s - loss: 0.9364 - accuracy: 0.5160 - val_loss: 1.0426 - val_accuracy: 0.4638
# Epoch 8/30
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 201/201 - 16s - loss: 0.9239 - accuracy: 0.5269 - val_loss: 1.0188 - val_accuracy: 0.4526
# Epoch 9/30
# Restoring model weights from the end of the best epoch.
# 201/201 - 16s - loss: 0.9067 - accuracy: 0.5321 - val_loss: 0.9463 - val_accuracy: 0.5144
# Epoch 00009: early stopping
#
# --- FASE 2: fine-tuning (CUT_LAYER=39, LR=5e-05) ---
# cut_layer=39 → 23,357,952/23,587,712 params trainable (99.0%)
# Epoch 1/30
# 201/201 - 34s - loss: 0.9926 - accuracy: 0.5140 - val_loss: 0.8190 - val_accuracy: 0.5861
# Epoch 2/30
# 201/201 - 34s - loss: 0.9334 - accuracy: 0.5360 - val_loss: 0.8585 - val_accuracy: 0.5799
# Epoch 3/30
# 201/201 - 34s - loss: 0.8742 - accuracy: 0.5803 - val_loss: 1.0567 - val_accuracy: 0.4894
# Epoch 4/30
# 201/201 - 34s - loss: 0.8437 - accuracy: 0.5864 - val_loss: 0.7891 - val_accuracy: 0.6024
# Epoch 5/30
# 201/201 - 34s - loss: 0.8139 - accuracy: 0.6026 - val_loss: 0.8424 - val_accuracy: 0.5805
# Epoch 6/30
# 201/201 - 34s - loss: 0.7908 - accuracy: 0.6024 - val_loss: 0.9434 - val_accuracy: 0.4850
# Epoch 7/30
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 201/201 - 34s - loss: 0.7664 - accuracy: 0.6198 - val_loss: 0.9829 - val_accuracy: 0.5019
# Epoch 8/30
# 201/201 - 34s - loss: 0.6961 - accuracy: 0.6510 - val_loss: 0.8053 - val_accuracy: 0.5861
# Epoch 9/30
# 201/201 - 34s - loss: 0.6699 - accuracy: 0.6569 - val_loss: 0.8869 - val_accuracy: 0.5737
# Epoch 10/30
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 201/201 - 34s - loss: 0.6148 - accuracy: 0.6904 - val_loss: 0.7942 - val_accuracy: 0.6149
# Epoch 11/30
# 201/201 - 34s - loss: 0.5375 - accuracy: 0.7229 - val_loss: 0.8555 - val_accuracy: 0.6298
# Epoch 12/30
# Restoring model weights from the end of the best epoch.
# 201/201 - 34s - loss: 0.5228 - accuracy: 0.7327 - val_loss: 0.7868 - val_accuracy: 0.6429
# Epoch 00012: early stopping
#
# --- Evaluación sobre test (2003 imgs) ---
#
# --- SYMMETRY ---
#               precision    recall  f1-score   support
#
#       2_ejes     0.7783    0.7674    0.7728      1208
#        1_eje     0.4456    0.2781    0.3425       604
#   asimetrica     0.3080    0.7016    0.4281       191
#
#     accuracy                         0.6136      2003
#    macro avg     0.5107    0.5824    0.5145      2003
# weighted avg     0.6332    0.6136    0.6102      2003
#   Pesos guardados en: ResNet50_STL/exp_2026-04-26_20-25_symmetry_CUT39_5fold/fold_3/best_weights
#
# ======================================================================
# FOLD 4/5 — STL symmetry
# ======================================================================
#   train=6409  val=1602  test(fijo)=2003
#
# --- FASE 1: warmup (head only, LR=0.001) ---
# Epoch 1/30
# 201/201 - 17s - loss: 1.1430 - accuracy: 0.4473 - val_loss: 0.9276 - val_accuracy: 0.5537
# Epoch 2/30
# 201/201 - 16s - loss: 1.0117 - accuracy: 0.4913 - val_loss: 1.0914 - val_accuracy: 0.4313
# Epoch 3/30
# 201/201 - 16s - loss: 0.9931 - accuracy: 0.4963 - val_loss: 0.9712 - val_accuracy: 0.5081
# Epoch 4/30
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 201/201 - 16s - loss: 0.9839 - accuracy: 0.4963 - val_loss: 1.0520 - val_accuracy: 0.4270
# Epoch 5/30
# 201/201 - 16s - loss: 0.9549 - accuracy: 0.5143 - val_loss: 1.0228 - val_accuracy: 0.4638
# Epoch 6/30
# 201/201 - 16s - loss: 0.9410 - accuracy: 0.5232 - val_loss: 0.9958 - val_accuracy: 0.4856
# Epoch 7/30
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 201/201 - 16s - loss: 0.9303 - accuracy: 0.5378 - val_loss: 1.0197 - val_accuracy: 0.4569
# Epoch 8/30
# Restoring model weights from the end of the best epoch.
# 201/201 - 16s - loss: 0.9162 - accuracy: 0.5319 - val_loss: 0.9357 - val_accuracy: 0.5262
# Epoch 00008: early stopping
#
# --- FASE 2: fine-tuning (CUT_LAYER=39, LR=5e-05) ---
# cut_layer=39 → 23,357,952/23,587,712 params trainable (99.0%)
# Epoch 1/30
# 201/201 - 35s - loss: 1.0645 - accuracy: 0.4296 - val_loss: 1.0043 - val_accuracy: 0.5518
# Epoch 2/30
# 201/201 - 34s - loss: 0.9869 - accuracy: 0.5035 - val_loss: 0.9185 - val_accuracy: 0.5125
# Epoch 3/30
# 201/201 - 34s - loss: 0.9355 - accuracy: 0.5190 - val_loss: 0.8793 - val_accuracy: 0.5306
# Epoch 4/30
# 201/201 - 34s - loss: 0.8727 - accuracy: 0.5508 - val_loss: 0.8622 - val_accuracy: 0.5599
# Epoch 5/30
# 201/201 - 34s - loss: 0.8599 - accuracy: 0.5595 - val_loss: 0.8061 - val_accuracy: 0.5980
# Epoch 6/30
# 201/201 - 34s - loss: 0.8354 - accuracy: 0.5853 - val_loss: 0.7889 - val_accuracy: 0.6067
# Epoch 7/30
# 201/201 - 34s - loss: 0.8034 - accuracy: 0.5960 - val_loss: 0.7677 - val_accuracy: 0.6242
# Epoch 8/30
# 201/201 - 34s - loss: 0.7863 - accuracy: 0.6020 - val_loss: 0.9058 - val_accuracy: 0.5787
# Epoch 9/30
# 201/201 - 34s - loss: 0.7568 - accuracy: 0.6146 - val_loss: 0.7976 - val_accuracy: 0.6061
# Epoch 10/30
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 201/201 - 34s - loss: 0.7305 - accuracy: 0.6198 - val_loss: 0.8418 - val_accuracy: 0.6074
# Epoch 11/30
# 201/201 - 34s - loss: 0.6814 - accuracy: 0.6594 - val_loss: 0.7577 - val_accuracy: 0.6280
# Epoch 12/30
# 201/201 - 34s - loss: 0.6442 - accuracy: 0.6765 - val_loss: 0.7784 - val_accuracy: 0.6180
# Epoch 13/30
# 201/201 - 34s - loss: 0.5887 - accuracy: 0.7020 - val_loss: 0.8851 - val_accuracy: 0.5755
# Epoch 14/30
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 201/201 - 34s - loss: 0.5741 - accuracy: 0.7099 - val_loss: 0.8037 - val_accuracy: 0.6467
# Epoch 15/30
# 201/201 - 34s - loss: 0.5069 - accuracy: 0.7344 - val_loss: 0.8318 - val_accuracy: 0.6342
# Epoch 16/30
# 201/201 - 34s - loss: 0.4755 - accuracy: 0.7461 - val_loss: 0.8589 - val_accuracy: 0.6467
# Epoch 17/30
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 201/201 - 34s - loss: 0.4532 - accuracy: 0.7658 - val_loss: 0.8483 - val_accuracy: 0.6392
# Epoch 18/30
# 201/201 - 34s - loss: 0.4191 - accuracy: 0.7811 - val_loss: 0.8698 - val_accuracy: 0.6598
# Epoch 19/30
# Restoring model weights from the end of the best epoch.
# 201/201 - 34s - loss: 0.3800 - accuracy: 0.7945 - val_loss: 0.9344 - val_accuracy: 0.6398
# Epoch 00019: early stopping
#
# --- Evaluación sobre test (2003 imgs) ---
#
# --- SYMMETRY ---
#               precision    recall  f1-score   support
#
#       2_ejes     0.8022    0.7790    0.7904      1208
#        1_eje     0.4676    0.3709    0.4137       604
#   asimetrica     0.3561    0.6545    0.4613       191
#
#     accuracy                         0.6440      2003
#    macro avg     0.5420    0.6014    0.5551      2003
# weighted avg     0.6588    0.6440    0.6454      2003
#   Pesos guardados en: ResNet50_STL/exp_2026-04-26_20-25_symmetry_CUT39_5fold/fold_4/best_weights
#
# ======================================================================
# FOLD 5/5 — STL symmetry
# ======================================================================
#   train=6409  val=1602  test(fijo)=2003
#
# --- FASE 1: warmup (head only, LR=0.001) ---
# Epoch 1/30
# 201/201 - 17s - loss: 1.1801 - accuracy: 0.4423 - val_loss: 0.9998 - val_accuracy: 0.5125
# Epoch 2/30
# 201/201 - 16s - loss: 1.0037 - accuracy: 0.4820 - val_loss: 0.9441 - val_accuracy: 0.5524
# Epoch 3/30
# 201/201 - 16s - loss: 0.9899 - accuracy: 0.5007 - val_loss: 0.9721 - val_accuracy: 0.5262
# Epoch 4/30
# 201/201 - 16s - loss: 0.9706 - accuracy: 0.5041 - val_loss: 1.0213 - val_accuracy: 0.4769
# Epoch 5/30
# 201/201 - 17s - loss: 0.9584 - accuracy: 0.5063 - val_loss: 0.9123 - val_accuracy: 0.5574
# Epoch 6/30
# 201/201 - 16s - loss: 0.9564 - accuracy: 0.5113 - val_loss: 1.0667 - val_accuracy: 0.4132
# Epoch 7/30
# 201/201 - 16s - loss: 0.9377 - accuracy: 0.5233 - val_loss: 0.8444 - val_accuracy: 0.6055
# Epoch 8/30
# 201/201 - 16s - loss: 0.9420 - accuracy: 0.5093 - val_loss: 0.9779 - val_accuracy: 0.5125
# Epoch 9/30
# 201/201 - 16s - loss: 0.9347 - accuracy: 0.5130 - val_loss: 1.0217 - val_accuracy: 0.4619
# Epoch 10/30
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 201/201 - 16s - loss: 0.9181 - accuracy: 0.5318 - val_loss: 0.9628 - val_accuracy: 0.5087
# Epoch 11/30
# 201/201 - 17s - loss: 0.8892 - accuracy: 0.5517 - val_loss: 0.9550 - val_accuracy: 0.4919
# Epoch 12/30
# 201/201 - 16s - loss: 0.8626 - accuracy: 0.5547 - val_loss: 0.9609 - val_accuracy: 0.5206
# Epoch 13/30
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 201/201 - 16s - loss: 0.8586 - accuracy: 0.5523 - val_loss: 0.9266 - val_accuracy: 0.5418
# Epoch 14/30
# Restoring model weights from the end of the best epoch.
# 201/201 - 16s - loss: 0.8349 - accuracy: 0.5701 - val_loss: 0.9709 - val_accuracy: 0.5087
# Epoch 00014: early stopping
#
# --- FASE 2: fine-tuning (CUT_LAYER=39, LR=5e-05) ---
# cut_layer=39 → 23,357,952/23,587,712 params trainable (99.0%)
# Epoch 1/30
# 201/201 - 35s - loss: 1.0461 - accuracy: 0.4452 - val_loss: 0.8937 - val_accuracy: 0.5456
# Epoch 2/30
# 201/201 - 34s - loss: 0.9137 - accuracy: 0.5564 - val_loss: 1.0021 - val_accuracy: 0.4800
# Epoch 3/30
# 201/201 - 34s - loss: 0.8719 - accuracy: 0.5694 - val_loss: 0.8673 - val_accuracy: 0.5774
# Epoch 4/30
# 201/201 - 34s - loss: 0.8286 - accuracy: 0.5865 - val_loss: 0.8335 - val_accuracy: 0.5861
# Epoch 5/30
# 201/201 - 34s - loss: 0.8082 - accuracy: 0.5893 - val_loss: 0.7886 - val_accuracy: 0.6280
# Epoch 6/30
# 201/201 - 34s - loss: 0.7783 - accuracy: 0.6096 - val_loss: 0.7877 - val_accuracy: 0.6174
# Epoch 7/30
# 201/201 - 34s - loss: 0.7508 - accuracy: 0.6240 - val_loss: 0.9335 - val_accuracy: 0.5637
# Epoch 8/30
# 201/201 - 34s - loss: 0.7320 - accuracy: 0.6333 - val_loss: 0.9555 - val_accuracy: 0.5125
# Epoch 9/30
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 201/201 - 34s - loss: 0.6968 - accuracy: 0.6424 - val_loss: 0.8052 - val_accuracy: 0.6342
# Epoch 10/30
# 201/201 - 34s - loss: 0.6051 - accuracy: 0.6858 - val_loss: 0.9025 - val_accuracy: 0.6223
# Epoch 11/30
# 201/201 - 34s - loss: 0.5784 - accuracy: 0.6950 - val_loss: 1.0324 - val_accuracy: 0.5306
# Epoch 12/30
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 201/201 - 34s - loss: 0.5455 - accuracy: 0.7135 - val_loss: 0.8625 - val_accuracy: 0.6161
# Epoch 13/30
# Restoring model weights from the end of the best epoch.
# 201/201 - 34s - loss: 0.4787 - accuracy: 0.7504 - val_loss: 0.8751 - val_accuracy: 0.6199
# Epoch 00013: early stopping
#
# --- Evaluación sobre test (2003 imgs) ---
#
# --- SYMMETRY ---
#               precision    recall  f1-score   support
#
#       2_ejes     0.7986    0.7417    0.7691      1208
#        1_eje     0.4657    0.4603    0.4629       604
#   asimetrica     0.3803    0.5654    0.4547       191
#
#     accuracy                         0.6400      2003
#    macro avg     0.5482    0.5891    0.5623      2003
# weighted avg     0.6583    0.6400    0.6468      2003
#   Pesos guardados en: ResNet50_STL/exp_2026-04-26_20-25_symmetry_CUT39_5fold/fold_5/best_weights
#
# ======================================================================
# *** Experimento STL symmetry completo en 65.0 min ***
# ======================================================================
#
# ======================================================================
# RESUMEN ENTRE 5 FOLDS — STL symmetry
# ======================================================================
#                                 mean      median         std
# time_warmup_s             206.440000  236.700000   57.251052
# time_ft_s                 566.160000  519.100000  156.005010
# time_total_s              772.620000  771.400000  176.428022
# time_predict_s              4.242000    4.240000    0.134981
# epochs_warmup              12.200000   14.000000    3.420526
# epochs_ft                  16.400000   15.000000    4.560702
# len_warmup                 12.200000   14.000000    3.420526
# symmetry_acc                0.637444    0.640040    0.015833
# symmetry_balanced_acc       0.584352    0.582367    0.012317
# symmetry_precision_macro    0.540899    0.541994    0.018902
# symmetry_recall_macro       0.584352    0.582367    0.012317
# symmetry_f1_macro           0.550426    0.555374    0.020543
# symmetry_f1_weighted        0.639899    0.645425    0.018068
# symmetry_kappa              0.347607    0.355802    0.020623
# symmetry_auc_macro          0.788027    0.787371    0.009007
#
# Guardado en: ResNet50_STL/exp_2026-04-26_20-25_symmetry_CUT39_5fold
#
# >>> Fase 1 (warmup)
# >>> Fase 2 (fine-tuning)
# >>> Entrenamiento completo (warmup + FT combinados)
#   Gráfica conjunta guardada: ResNet50_STL/exp_2026-04-26_20-25_symmetry_CUT39_5fold/training_plots_cv/combined_full_training.png
#
# >>> Matriz de confusión agregada entre folds
#   Guardado: ResNet50_STL/exp_2026-04-26_20-25_symmetry_CUT39_5fold/confusion_matrix_symmetry_aggregated.png

# %%
import cv2

#Parámetros 
GRADCAM_LAYER   = "conv5_block3_out"
SEG_MASKS_PATH  = "/home/marc/MARIADELMAR_EXPERIMENTS/dataverse_files/binary_seg/HAM10000_segmentations_lesion_tschandl"

#Mejor fold 
best_metric_col = f"{TASK_NAME}_balanced_acc"
best_fold_idx   = int(df_metrics[best_metric_col].idxmax()) + 1
print(f"Usando fold {best_fold_idx}  "
      f"({best_metric_col}={df_metrics[best_metric_col].max():.4f})")

fold_dir_best = EXP_DIR / f"fold_{best_fold_idx}"
weights_path  = fold_dir_best / "best_weights"

#Reconstruir modelo y cargar pesos
backbone_gc, base_gc = build_model()
for imgs, _ in test_ds.take(1):
    _ = backbone_gc(imgs[:1], training=False)
if (fold_dir_best / "best_weights.index").exists():
    backbone_gc.load_weights(str(weights_path))
    print(f"Pesos cargados desde {weights_path}")
else:
    print(f"[AVISO] No se encontró {weights_path}.index")


#GradCAM 
def make_gradcam_heatmap(img_array, model, class_idx):
    resnet_sub = model.get_layer("resnet50")              
    last_conv_name = "conv5_block3_out"                   

    resnet_dual = tf.keras.Model(
        inputs=resnet_sub.input,
        outputs=[
            resnet_sub.get_layer(last_conv_name).output,
            resnet_sub.output,
        ],
    )

    gap_layer    = model.get_layer("gap")
    shared_dense = model.get_layer("shared_dense")
    shared_drop  = model.get_layer("shared_dropout")
    head_sym     = model.get_layer("head_sym")

    with tf.GradientTape() as tape:
        conv_outputs, resnet_final = resnet_dual(img_array, training=False)
        x           = gap_layer(resnet_final)
        x           = shared_dense(x)
        x           = shared_drop(x, training=False)
        predictions = head_sym(x)
        loss        = predictions[:, class_idx]

    grads        = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    heatmap      = conv_outputs[0] @ pooled_grads[..., tf.newaxis]
    heatmap      = tf.squeeze(heatmap)
    heatmap      = tf.maximum(heatmap, 0)
    heatmap      = heatmap / (tf.math.reduce_max(heatmap) + 1e-8)
    return heatmap.numpy()



def overlay_heatmap(img_orig, heatmap, alpha=0.45):
    heatmap_r = cv2.resize(heatmap, (img_orig.shape[1], img_orig.shape[0]))
    colored   = cv2.applyColorMap((heatmap_r * 255).astype(np.uint8), cv2.COLORMAP_JET)
    colored   = cv2.cvtColor(colored, cv2.COLOR_BGR2RGB)
    return (alpha * colored + (1 - alpha) * img_orig).astype(np.uint8)


def load_img_for_gradcam(filepath):
    raw      = tf.io.read_file(filepath)
    raw      = tf.image.decode_image(raw, channels=3, expand_animations=False)
    raw      = tf.image.resize(raw, IMG_SIZE)
    img_orig = raw.numpy().astype(np.uint8)
    img_pre  = tf.keras.applications.resnet.preprocess_input(tf.cast(raw, tf.float32))  
    return img_orig, tf.expand_dims(img_pre, 0)


def load_lesion_mask(image_id):
    """Carga la máscara binaria de la lesión y la redimensiona a IMG_SIZE."""
    mask_path = os.path.join(SEG_MASKS_PATH, f"{image_id}_segmentation.png")
    if not os.path.exists(mask_path):
        return None
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    if mask is None:
        return None
    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)
    return mask


#Plot matriz por clase (con máscaras) 
def plot_gradcam_by_class(df_test, y_true_int, y_pred_int, y_pred_proba,
                           backbone_model, class_names, fold_label="", save_dir=None):
    """
    Matriz 6 x n_clases:
      Fila 1: MAL clasificadas (imagen original)
      Fila 2: GradCAM overlay (mal)
      Fila 3: Máscara lesión (mal)
      Fila 4: BIEN clasificadas (imagen original)
      Fila 5: GradCAM overlay (bien)
      Fila 6: Máscara lesión (bien)
    """
    n_cls = len(class_names)
    fig, axes = plt.subplots(6, n_cls, figsize=(3 * n_cls, 18))
    if n_cls == 1:
        axes = axes[:, np.newaxis]

    fig.suptitle(f"{fold_label} GradCAM + máscara - Tarea: {TASK_NAME}",
                 fontsize=13, fontweight="bold", y=0.995)

    for ci, cname in enumerate(class_names):
        #MAL clasificadas 
        mask_bad = (y_true_int == ci) & (y_pred_int != ci)
        idx_bad  = np.where(mask_bad)[0]
        if len(idx_bad) > 0:
            confidences = y_pred_proba[idx_bad, y_pred_int[idx_bad]]
            best        = idx_bad[np.argmax(confidences)]
            top2_idx    = np.argsort(y_pred_proba[best])[::-1][:2]
            top1_cls    = class_names[top2_idx[0]]
            top2_cls    = class_names[top2_idx[1]]
            top1_prob   = y_pred_proba[best, top2_idx[0]]
            top2_prob   = y_pred_proba[best, top2_idx[1]]

            filepath    = df_test.iloc[best]["filepath"]
            image_id    = df_test.iloc[best]["image_id"]
            img_orig, img_pre = load_img_for_gradcam(filepath)
            heatmap  = make_gradcam_heatmap(img_pre, backbone_model, class_idx=int(top2_idx[0]))
            overlay  = overlay_heatmap(img_orig, heatmap)
            seg_mask = load_lesion_mask(image_id)

            axes[0, ci].imshow(img_orig)
            axes[0, ci].set_title(
                f"{cname} | {image_id}\ntrue: {cname}\n"
                f"top1: {top1_cls} ({top1_prob:.4f})\n"
                f"top2: {top2_cls} ({top2_prob:.4f})",
                fontsize=6, color="red")
            axes[1, ci].imshow(overlay)
            if seg_mask is not None:
                axes[2, ci].imshow(seg_mask, cmap="gray")
            else:
                axes[2, ci].text(0.5, 0.5, "máscara\nno disponible",
                                 ha="center", va="center", fontsize=7)
        else:
            for r in range(3):
                axes[r, ci].text(0.5, 0.5, f"{cname}\nNo hay\nmalas",
                                 ha="center", va="center", fontsize=8)

        #BIEN clasificadas 
        mask_good = (y_true_int == ci) & (y_pred_int == ci)
        idx_good  = np.where(mask_good)[0]
        if len(idx_good) > 0:
            confidences = y_pred_proba[idx_good, ci]
            best        = idx_good[np.argmax(confidences)]
            top2_idx    = np.argsort(y_pred_proba[best])[::-1][:2]
            top1_cls    = class_names[top2_idx[0]]
            top2_cls    = class_names[top2_idx[1]]
            top1_prob   = y_pred_proba[best, top2_idx[0]]
            top2_prob   = y_pred_proba[best, top2_idx[1]]

            filepath    = df_test.iloc[best]["filepath"]
            image_id    = df_test.iloc[best]["image_id"]
            img_orig, img_pre = load_img_for_gradcam(filepath)
            heatmap  = make_gradcam_heatmap(img_pre, backbone_model, class_idx=int(ci))
            overlay  = overlay_heatmap(img_orig, heatmap)
            seg_mask = load_lesion_mask(image_id)

            axes[3, ci].imshow(img_orig)
            axes[3, ci].set_title(
                f"{cname} | {image_id}\ntrue: {cname}\n"
                f"top1: {top1_cls} ({top1_prob:.4f})\n"
                f"top2: {top2_cls} ({top2_prob:.4f})",
                fontsize=6, color="green")
            axes[4, ci].imshow(overlay)
            if seg_mask is not None:
                axes[5, ci].imshow(seg_mask, cmap="gray")
            else:
                axes[5, ci].text(0.5, 0.5, "máscara\nno disponible",
                                 ha="center", va="center", fontsize=7)
        else:
            for r in range(3, 6):
                axes[r, ci].text(0.5, 0.5, f"{cname}\nNo hay\nbuenas",
                                 ha="center", va="center", fontsize=8)

        for r in range(6):
            axes[r, ci].axis("off")

    row_labels = [
        "MAL clasificadas\n(alta confianza)",
        "GradCAM (mal)",
        "Máscara lesión (mal)",
        "BIEN clasificadas\n(alta confianza)",
        "GradCAM (bien)",
        "Máscara lesión (bien)",
    ]
    for r, label in enumerate(row_labels):
        axes[r, 0].text(-0.15, 0.5, label, transform=axes[r, 0].transAxes,
                        fontsize=9, rotation=90, va="center", ha="right",
                        fontweight="bold")

    plt.tight_layout(rect=[0, 0, 1, 0.97])
    if save_dir:
        out = Path(save_dir) / f"gradcam_{TASK_NAME}_by_class.png"
        plt.savefig(out, dpi=150, bbox_inches="tight")
        print(f"  Guardado: {out}")
    plt.show()


#Recomputar predicciones 
print("\nRecomputando predicciones del fold seleccionado...")
y_pred_proba_gc = backbone_gc.predict(test_ds, verbose=0)
y_pred_int_gc   = np.argmax(y_pred_proba_gc, axis=1)

gradcam_dir = EXP_DIR / "gradcam"
gradcam_dir.mkdir(exist_ok=True)
fold_label  = f"Fold {best_fold_idx} -"

print(f"\n=== GradCAM - Tarea: {TASK_NAME.upper()} (matriz por clase con máscaras) ===")
plot_gradcam_by_class(
    df_test, y_test_int, y_pred_int_gc, y_pred_proba_gc,
    backbone_gc, class_names=class_names,
    fold_label=fold_label, save_dir=str(gradcam_dir))

print(f"\nImágenes GradCAM guardadas en: {gradcam_dir.resolve()}")
# Out:
# Usando fold 4  (symmetry_balanced_acc=0.6014)
# Pesos cargados desde ResNet50_STL/exp_2026-04-26_20-25_symmetry_CUT39_5fold/fold_4/best_weights
#
# Recomputando predicciones del fold seleccionado...
#
# === GradCAM — Tarea: SYMMETRY (matriz por clase con máscaras) ===
#   Guardado: ResNet50_STL/exp_2026-04-26_20-25_symmetry_CUT39_5fold/gradcam/gradcam_symmetry_by_class.png
# Imágenes GradCAM guardadas en: /home/marc/MARIADELMAR_EXPERIMENTS/STL_Symmetry_experimentos/ResNet50_STL/exp_2026-04-26_20-25_symmetry_CUT39_5fold/gradcam

# %%
#Recomputar métricas añadiendo precision y recall 
print("Recomputando métricas con precision/recall macro desde pesos guardados...\n")

updated_rows = []
for fold_idx in range(1, N_FOLDS + 1):
    fold_dir_k = EXP_DIR / f"fold_{fold_idx}"
    weights_k  = fold_dir_k / "best_weights"

    if not (fold_dir_k / "best_weights.index").exists():
        print(f"  [AVISO] fold {fold_idx}: no hay pesos, se salta")
        continue

    tf.keras.backend.clear_session()
    model_k, base_k = build_model()
    for imgs, _ in test_ds.take(1):
        _ = model_k(imgs[:1], training=False)
    model_k.load_weights(str(weights_k))

    y_pred_proba = model_k.predict(test_ds, verbose=0)
    y_pred_int   = np.argmax(y_pred_proba, axis=1)

    # Recuperar la fila existente y añadir las nuevas columnas
    row = df_metrics[df_metrics["fold"] == fold_idx].iloc[0].to_dict()
    row[f"{TASK_NAME}_precision_macro"] = float(
        precision_score(y_test_int, y_pred_int, average="macro", zero_division=0))
    row[f"{TASK_NAME}_recall_macro"] = float(
        recall_score(y_test_int, y_pred_int, average="macro", zero_division=0))

    updated_rows.append(row)
    print(f"  fold {fold_idx}: precision={row[f'{TASK_NAME}_precision_macro']:.4f}  "
          f"recall={row[f'{TASK_NAME}_recall_macro']:.4f}")

#Reconstruir df_metrics y summary 
df_metrics = pd.DataFrame(updated_rows)
df_metrics.to_csv(EXP_DIR / "all_folds_metrics.csv", index=False)

numeric  = [c for c in df_metrics.columns
            if c != "fold" and pd.api.types.is_numeric_dtype(df_metrics[c])]
summary  = df_metrics[numeric].agg(["mean", "median", "std"]).T
summary.columns = ["mean", "median", "std"]
summary["mean±std"] = summary.apply(
    lambda r: f"{r['mean']:.4f} ± {r['std']:.4f}", axis=1)
summary.to_csv(EXP_DIR / "summary_mean_median_std.csv")

print("\n df_metrics y summary actualizados")
print("\nNuevas métricas en summary:")
print(summary.loc[[i for i in summary.index if "precision" in i or "recall" in i]])
# Out:
# Recomputando métricas con precision/recall macro desde pesos guardados...
#
#   fold 1: precision=0.5624  recall=0.5677
#   fold 2: precision=0.5413  recall=0.5811
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-22.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-22.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-23.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-23.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-24.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-24.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-25.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-25.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-26.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-26.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-27.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-27.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-28.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-28.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-29.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-29.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-30.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-30.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-31.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-31.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-32.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-32.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-33.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-33.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-34.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-34.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-35.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-35.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-36.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-36.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-37.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-37.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-38.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-38.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-39.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-39.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-40.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-40.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-41.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-41.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-42.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-42.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-43.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-43.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-44.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-44.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-45.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-45.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-46.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-46.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-47.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-47.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-48.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-48.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-49.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-49.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-50.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-50.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-51.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-51.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-52.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-52.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-53.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-53.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-54.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-54.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-55.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-55.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-56.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-56.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-57.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-57.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-58.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-58.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-59.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-59.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-60.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-60.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-61.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-61.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-62.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-62.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-63.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-63.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-64.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-64.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-65.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-65.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-66.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-66.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-67.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-67.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-68.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-68.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-69.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-69.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-70.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-70.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-71.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-71.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-72.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-72.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-73.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-73.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-74.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-74.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-75.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-75.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-76.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-76.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-77.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-77.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-78.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-78.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-79.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-79.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-80.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-80.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-81.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-81.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-82.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-82.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-83.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-83.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-84.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-84.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-85.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-85.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-86.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-86.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-87.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-87.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-88.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-88.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-89.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-89.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-90.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-90.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-91.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-91.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-92.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-92.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-93.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-93.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-94.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-94.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-95.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-95.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-96.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-96.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-97.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-97.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-98.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-98.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-99.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-99.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-100.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-100.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-101.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-101.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-102.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-102.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-103.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-103.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-104.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-104.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-105.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.layer_with_weights-105.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-22.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-22.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-23.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-23.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-24.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-24.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-25.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-25.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-26.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-26.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-27.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-27.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-28.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-28.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-29.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-29.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-30.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-30.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-31.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-31.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-32.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-32.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-33.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-33.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-34.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-34.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-35.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-35.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-36.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-36.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-37.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-37.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-38.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-38.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-39.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-39.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-40.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-40.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-41.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-41.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-42.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-42.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-43.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-43.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-44.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-44.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-45.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-45.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-46.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-46.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-47.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-47.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-48.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-48.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-49.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-49.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-50.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-50.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-51.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-51.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-52.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-52.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-53.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-53.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-54.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-54.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-55.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-55.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-56.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-56.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-57.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-57.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-58.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-58.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-59.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-59.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-60.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-60.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-61.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-61.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-62.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-62.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-63.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-63.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-64.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-64.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-65.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-65.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-66.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-66.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-67.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-67.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-68.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-68.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-69.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-69.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-70.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-70.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-71.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-71.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-72.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-72.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-73.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-73.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-74.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-74.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-75.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-75.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-76.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-76.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-77.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-77.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-78.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-78.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-79.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-79.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-80.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-80.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-81.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-81.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-82.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-82.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-83.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-83.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-84.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-84.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-85.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-85.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-86.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-86.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-87.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-87.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-88.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-88.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-89.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-89.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-90.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-90.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-91.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-91.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-92.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-92.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-93.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-93.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-94.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-94.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-95.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-95.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-96.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-96.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-97.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-97.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-98.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-98.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-99.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-99.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-100.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-100.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-101.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-101.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-102.kernel
# ...
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-52.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-52.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-53.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-53.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-54.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-54.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-55.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-55.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-56.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-56.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-57.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-57.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-58.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-58.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-59.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-59.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-60.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-60.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-61.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-61.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-62.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-62.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-63.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-63.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-64.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-64.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-65.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-65.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-66.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-66.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-67.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-67.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-68.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-68.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-69.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-69.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-70.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-70.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-71.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-71.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-72.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-72.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-73.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-73.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-74.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-74.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-75.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-75.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-76.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-76.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-77.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-77.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-78.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-78.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-79.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-79.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-80.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-80.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-81.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-81.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-82.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-82.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-83.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-83.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-84.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-84.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-85.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-85.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-86.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-86.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-87.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-87.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-88.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-88.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-89.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-89.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-90.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-90.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-91.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-91.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-92.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-92.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-93.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-93.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-94.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-94.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-95.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-95.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-96.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-96.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-97.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-97.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-98.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-98.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-99.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-99.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-100.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-100.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-101.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-101.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-102.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-102.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-103.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-103.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-104.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-104.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-105.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-105.beta
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
#   fold 5: precision=0.5482  recall=0.5891
#
# ✓ df_metrics y summary actualizados
#
# Nuevas métricas en summary:
#                               mean    median       std         mean±std
# symmetry_precision_macro  0.540899  0.541994  0.018902  0.5409 ± 0.0189
# symmetry_recall_macro     0.584352  0.582367  0.012317  0.5844 ± 0.0123

# %%
def build_final_pdf():
    pdf_path    = EXP_DIR / "FINAL_REPORT.pdf"
    plots_dir   = EXP_DIR / "training_plots_cv"
    gradcam_dir = EXP_DIR / "gradcam"

    with PdfPages(pdf_path) as pdf:

        #Portada
        fig = plt.figure(figsize=(11, 8.5))
        fig.text(0.5, 0.92, f"STL ({TASK_NAME}) - Reporte final",
                 ha="center", fontsize=20, fontweight="bold")
        fig.text(0.5, 0.87, f"ResNet50  |  CUT_LAYER={CUT_LAYER}  |  K={N_FOLDS} folds",
                 ha="center", fontsize=13, style="italic")
        fig.text(0.5, 0.83, EXP_DIR.name,
                 ha="center", fontsize=9, family="monospace")

        info  = "Arquitectura: ResNet50 + GAP + shared_dense(256) + dropout(0.3) + 1 cabeza\n\n"
        info += f"Tarea: {TASK_NAME} ({NUM_CLASSES} clases)\n"
        info += f"  Clases: {', '.join(class_names)}\n\n"
        info += "Configuracion de entrenamiento:\n"
        info += f"  - Warmup:       LR={WARMUP_LR}, epochs max={WARMUP_EPOCHS}, patience ES=7, patience LR=3\n"
        info += f"  - Fine-tuning:  LR={FT_LR}, epochs max={FT_EPOCHS}, patience ES=8, patience LR=3\n"
        info += f"  - Batch size: {BATCH_SIZE}, image size: {IMG_SIZE[0]}x{IMG_SIZE[1]}\n\n"
        info += "Protocolo: transfer learning estandar (TF/Keras oficial, CS231n)\n"
        info += "  - Fase 1: heads entrenables con LR alto\n"
        info += "  - Fase 2: backbone descongelado con LR reducido\n\n"
        info += "Class weights balanceados aplicados a la tarea\n\n"
        info += "Dataset:\n"
        info += f"  - train+val (CV): {len(df_trainval)} imagenes\n"
        info += f"  - test (fijo):    {len(df_test)} imagenes\n\n"
        info += f"Tiempo total experimento: {t_exp_total/60:.1f} min"

        fig.text(0.08, 0.75, info, fontsize=9, family="monospace", va="top")
        plt.axis("off")
        pdf.savefig(fig); plt.close(fig)

        #Resumen ejecutivo 
        fig, ax = plt.subplots(figsize=(12, 6))
        ax.axis("off")
        ax.set_title(f"Resumen ejecutivo - metricas de clasificacion ({N_FOLDS} folds)",
                     fontsize=14, fontweight="bold", pad=20)

        task_metrics_list = [
            (f"{TASK_NAME}_acc",             "Accuracy"),
            (f"{TASK_NAME}_balanced_acc",    "Balanced Acc"),
            (f"{TASK_NAME}_precision_macro", "Precision macro"),   
            (f"{TASK_NAME}_recall_macro",    "Recall macro"),      
            (f"{TASK_NAME}_f1_macro",        "F1 macro"),
            (f"{TASK_NAME}_auc_macro",       "AUC macro"),
            (f"{TASK_NAME}_kappa",           "Kappa"),
        ]

        

        rows       = []
        row_colors = []
        rows.append([f"{TASK_NAME.capitalize()} ({NUM_CLASSES} clases)", "", "", ""])
        row_colors.append(["#d9e1f2"] * 4)
        for metric_key, label in task_metrics_list:
            if metric_key in summary.index:
                mean   = summary.loc[metric_key, "mean"]
                median = summary.loc[metric_key, "median"]
                std    = summary.loc[metric_key, "std"]
                rows.append([f"  {label}",
                             f"{mean:.4f}",
                             f"{median:.4f}",
                             f"{std:.4f}"])
                if metric_key == "auc_melanoma":
                    row_colors.append(["#fce4d6"] * 4)
                else:
                    row_colors.append(["white"] * 4)

        tbl = ax.table(
            cellText=rows,
            colLabels=["Metrica", "Media", "Mediana", "Desv. tipica"],
            loc="center",
            cellLoc="left",
            cellColours=row_colors,
            colColours=["#305496"] * 4,
        )
        tbl.auto_set_font_size(False)
        tbl.set_fontsize(10)
        tbl.scale(1, 1.8)
        for j in range(4):
            tbl[(0, j)].set_text_props(color="white", fontweight="bold")

        pdf.savefig(fig, bbox_inches="tight"); plt.close(fig)

        #Tabla resumen completa 
        fig, ax = plt.subplots(figsize=(13, 8.5))
        ax.axis("off")
        ax.set_title(f"Resumen completo entre folds (K={N_FOLDS}) - mean / median / std",
                     fontsize=14, fontweight="bold", pad=20)
        tbl = ax.table(
            cellText=[[i, f"{r['mean']:.4f}", f"{r['median']:.4f}", f"{r['std']:.4f}"]
                      for i, r in summary.iterrows()],
            colLabels=["metrica", "mean", "median", "std"],
            loc="center", cellLoc="left",
        )
        tbl.auto_set_font_size(False); tbl.set_fontsize(7); tbl.scale(1, 1.4)
        pdf.savefig(fig); plt.close(fig)

        #Tabla metricas por fold 
        fig, ax = plt.subplots(figsize=(14, 8.5))
        ax.axis("off")
        ax.set_title(f"Metricas por fold - STL {TASK_NAME}",
                     fontsize=14, fontweight="bold", pad=20)
        cols = [
            "fold",
            f"{TASK_NAME}_acc", f"{TASK_NAME}_balanced_acc",
            f"{TASK_NAME}_f1_macro", f"{TASK_NAME}_auc_macro", f"{TASK_NAME}_kappa",
        ]
        if TASK_NAME == "disease" and "auc_melanoma" in df_metrics.columns:
            cols.append("auc_melanoma")
        cols += ["time_total_s", "epochs_warmup", "epochs_ft"]

        df_show = df_metrics[cols].copy()
        for c in df_show.columns:
            if c != "fold":
                df_show[c] = df_show[c].round(4)
        tbl = ax.table(
            cellText=df_show.values.tolist(),
            colLabels=cols, loc="center", cellLoc="center",
        )
        tbl.auto_set_font_size(False); tbl.set_fontsize(7); tbl.scale(1, 1.4)
        pdf.savefig(fig); plt.close(fig)

        #Grafica conjunta warmup + FT 
        p_combined = plots_dir / "combined_full_training.png"
        if p_combined.exists():
            fig = plt.figure(figsize=(14, 5))
            plt.imshow(plt.imread(str(p_combined))); plt.axis("off")
            plt.title("Entrenamiento completo - warmup + fine-tuning (mean ± std)",
                      fontsize=12, fontweight="bold")
            pdf.savefig(fig); plt.close(fig)

        #Fases separadas 
        for phase, title in [("phase1_warmup",   "Warmup - loss/acc (mean ± std)"),
                              ("phase2_finetune", "Fine-tuning - loss/acc (mean ± std)")]:
            p = plots_dir / f"{phase}_cv_mean_std.png"
            if p.exists():
                fig = plt.figure(figsize=(13, 5))
                plt.imshow(plt.imread(str(p))); plt.axis("off")
                plt.title(title, fontsize=12, fontweight="bold")
                pdf.savefig(fig); plt.close(fig)

        #Matriz de confusion agregada
        p = EXP_DIR / f"confusion_matrix_{TASK_NAME}_aggregated.png"
        if p.exists():
            fig = plt.figure(figsize=(14, 6))
            plt.imshow(plt.imread(str(p))); plt.axis("off")
            plt.title(f"Matriz de confusion agregada - {TASK_NAME} ({NUM_CLASSES} clases)",
                      fontsize=12, fontweight="bold")
            pdf.savefig(fig, bbox_inches="tight"); plt.close(fig)

        #GradCAM por clase 
        p = gradcam_dir / f"gradcam_{TASK_NAME}_by_class.png"
        if p.exists():
            img_data = plt.imread(str(p))
            h, w     = img_data.shape[:2]
            fig = plt.figure(figsize=(11, 11 * h / w))
            plt.imshow(img_data); plt.axis("off")
            plt.title(f"GradCAM buenas/malas por clase - {TASK_NAME}",
                      fontsize=12, fontweight="bold")
            pdf.savefig(fig, bbox_inches="tight"); plt.close(fig)

        #Detalle por fold 
        for k in range(1, N_FOLDS + 1):
            fd = EXP_DIR / f"fold_{k}"

            p = fd / f"confusion_matrix_{TASK_NAME}.png"
            if p.exists():
                fig = plt.figure(figsize=(10, 7))
                plt.imshow(plt.imread(str(p))); plt.axis("off")
                plt.title(f"Fold {k} - Matriz confusion - {TASK_NAME}",
                          fontsize=11, fontweight="bold")
                pdf.savefig(fig); plt.close(fig)

            rpt = fd / f"classification_report_{TASK_NAME}.txt"
            if rpt.exists():
                fig = plt.figure(figsize=(11, 8.5)); plt.axis("off")
                plt.title(f"Fold {k} - Classification report - {TASK_NAME}",
                          fontsize=11, fontweight="bold", loc="left")
                plt.text(0.05, 0.95, rpt.read_text(),
                         fontsize=10, family="monospace", va="top")
                pdf.savefig(fig); plt.close(fig)

    print(f"PDF guardado en: {pdf_path.resolve()}")
    return pdf_path

_ = build_final_pdf()
# Out:
# PDF guardado en: /home/marc/MARIADELMAR_EXPERIMENTS/STL_Symmetry_experimentos/ResNet50_STL/exp_2026-04-26_20-25_symmetry_CUT39_5fold/FINAL_REPORT.pdf
